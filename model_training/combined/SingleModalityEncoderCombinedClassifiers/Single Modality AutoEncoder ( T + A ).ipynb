# %% [markdown]
# # Single Modality AutoEncoder ( T + A )

# %% [markdown]
# ## Imports

# %%
import torch
from torch.utils.data import Dataset

import os
import torch
import torch.nn as nn
from torch.utils.data import DataLoader
import numpy as np
from collections import defaultdict
import json
import torch.optim as optim
from torch.nn import TransformerEncoder, TransformerEncoderLayer

# %% [markdown]
# # Dataset

# %%
class MultimodalDataset(Dataset):
    def __init__(self, base_path, split, bert_feature_size='bert_text_features_128'):
        """
        Initialize the dataset by loading the tensor files.

        :param base_path: The path where the .pt files are stored
        :param split: The data split to load ('train', 'validate', or 'test')
        :param bert_feature_size: The size of the BERT features to load
        """
        self.audio_features = torch.load(f'{base_path}/{split}_audio_features.pt')
        self.facial_features = torch.load(f'{base_path}/{split}_facial_features.pt')
        self.bert_features = torch.load(f'{base_path}/{split}_{bert_feature_size}.pt')
        self.labels = torch.load(f'{base_path}/{split}_labels.pt')

    def __len__(self):
        return len(self.labels)

    def __getitem__(self, idx):
        return {
            'audio_features': self.audio_features[idx],
            'facial_features': self.facial_features[idx],
            'bert_features': self.bert_features[idx],
            'label': self.labels[idx]
        }

# %%
# Assuming the data is saved in './tensor_data' directory
base_path = './tensor_data'
bert_feature_size = 'bert_text_features_512'  # or 256, 128 based on what is needed

# %% [markdown]
# ### Common Trainer Class

# %%
class ModelTrainer:
    def __init__(self, model, train_dataset, val_dataset, model_name, epochs, save_interval, lr=1e-3, device='cuda'):
        self.model = model.to(device)
        self.train_dataset = train_dataset
        self.val_dataset = val_dataset
        self.model_name = model_name
        self.start_epoch = 0
        self.epochs = epochs
        self.save_interval = save_interval
        self.lr = lr
        self.device = device
        self.history = defaultdict(list)
        self.checkpoint_dir = f'modelCheckPoints/{self.model_name}'
        os.makedirs(self.checkpoint_dir, exist_ok=True)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=self.lr)

    def save_checkpoint(self, epoch):
        state = {'epoch': epoch, 'state_dict': self.model.state_dict()}
        torch.save(state, f'{self.checkpoint_dir}/{epoch}.pt')

    def load_checkpoint(self):
        checkpoints = [ckpt for ckpt in os.listdir(self.checkpoint_dir) if ckpt.endswith('.pt')]
        if checkpoints:
            latest_checkpoint = max(checkpoints, key=lambda x: int(x.split('.')[0]))
            checkpoint = torch.load(f'{self.checkpoint_dir}/{latest_checkpoint}', map_location=self.device)
            self.model.load_state_dict(checkpoint['state_dict'])
            self.start_epoch = checkpoint['epoch'] + 1
            print(f"Loaded checkpoint: {latest_checkpoint} at epoch {checkpoint['epoch']}")
        else:
            print("No checkpoints found, starting from scratch.")

    def save_history(self):
        with open(f'{self.checkpoint_dir}/history.json', 'w') as f:
            json.dump(self.history, f)

    def train_one_epoch(self, dataloader, criterion, max_grad_norm=1.0):
        self.model.train()
        total_loss = 0
        correct_predictions = 0
    
        for batch in dataloader:
            audio_features = batch['audio_features'].to(self.device)
            bert_features = batch['bert_features'].to(self.device)
            labels = batch['label'].to(self.device)
    
            self.optimizer.zero_grad()
            outputs = self.model(audio_features, bert_features)
    
            loss = criterion(outputs, labels)
            loss.backward()
            torch.nn.utils.clip_grad_norm_(self.model.parameters(), max_grad_norm)
            self.optimizer.step()
    
            total_loss += loss.item()
            _, predicted = torch.max(outputs, 1)
            correct_predictions += (predicted == labels).sum().item()
    
        avg_loss = total_loss / len(dataloader.dataset)
        accuracy = correct_predictions / len(dataloader.dataset)
        return avg_loss, accuracy

    def validate(self, dataloader, criterion):
        self.model.eval()
        total_loss = 0
        correct_predictions = 0
        
        with torch.no_grad():
            for batch in dataloader:
                audio = batch['audio_features'].to(self.device)
                # vision = batch['vision'].to(self.device)
                text_bert = batch['bert_features'].to(self.device)
                labels = batch['label'].to(self.device)
        
                outputs = self.model(audio, text_bert)
                loss = criterion(outputs, labels)
                total_loss += loss.item()
                _, predicted = torch.max(outputs, 1)
                correct_predictions += (predicted == labels).sum().item()
        
        avg_loss = total_loss / len(dataloader.dataset)
        accuracy = correct_predictions / len(dataloader.dataset)
        return avg_loss, accuracy


    def train(self, criterion):
        self.load_checkpoint()
        train_dataloader = DataLoader(train_dataset, batch_size=512, shuffle=True, drop_last=True)
        val_dataloader = DataLoader(val_dataset, batch_size=512, shuffle=False, drop_last=True)

        for epoch in range(self.start_epoch, self.epochs):
            train_loss, train_acc = self.train_one_epoch(train_dataloader, criterion)
            val_loss, val_acc = self.validate(val_dataloader, criterion)
    
            self.history['train_loss'].append(train_loss)
            self.history['train_acc'].append(train_acc)
            self.history['val_loss'].append(val_loss)
            self.history['val_acc'].append(val_acc)
    
            print(f"Epoch {epoch+1}/{self.epochs}, Train Loss: {train_loss:.4f}, Train Accuracy: {train_acc:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_acc:.4f}")
    
            if (epoch + 1) % self.save_interval == 0:
                self.save_checkpoint(epoch + 1)
    
            self.save_history()

# %% [markdown]
# ### Dynamic Encoder

# %%
class DynamicEncoder(nn.Module):
    def __init__(self, input_size, encoded_size=128, depth=1, dropout_rate=0.5):
        super(DynamicEncoder, self).__init__()
        layers = []

        current_size = input_size
        for i in range(depth - 1):  # Reserve the last layer to ensure it outputs encoded_size
            next_size = max(encoded_size, current_size // 2)
            layers.append(nn.Linear(current_size, next_size))
            layers.append(nn.ReLU())
            layers.append(nn.Dropout(dropout_rate))
            current_size = next_size

        # Ensure the last layer has the correct output size
        layers.append(nn.Linear(current_size, encoded_size))
        layers.append(nn.ReLU())
        layers.append(nn.Dropout(dropout_rate))

        self.encoder = nn.Sequential(*layers)

    def forward(self, x):
        return self.encoder(x)


class CombinedClassifier(nn.Module):
    def __init__(self, bert_feature_size, audio_feature_size, num_classes, encoded_audio_size=128, encoded_text_size=128, audio_depth=1, text_depth=1, classifier_size=512, classifier_depth=1, audio_dropout_rate=0.5, text_dropout_rate=0.5, classifier_dropout_rate=0.5):
        super(CombinedClassifier, self).__init__()
        self.audio_encoder = DynamicEncoder(audio_feature_size, encoded_audio_size, audio_depth, audio_dropout_rate)
        self.text_encoder = DynamicEncoder(bert_feature_size, encoded_text_size, text_depth, text_dropout_rate)
        
        combined_feature_size = encoded_audio_size + encoded_text_size 
        classifier_layers = [nn.Linear(combined_feature_size, classifier_size), nn.ReLU(), nn.Dropout(classifier_dropout_rate)]
        
        for _ in range(1, classifier_depth):
            classifier_layers.append(nn.Linear(classifier_size, classifier_size))
            classifier_layers.append(nn.ReLU())
            classifier_layers.append(nn.Dropout(classifier_dropout_rate))

        classifier_layers.append(nn.Linear(classifier_size, num_classes))
        self.classifier = nn.Sequential(*classifier_layers)

    def forward(self, audio_features, bert_features):
        encoded_audio = self.audio_encoder(audio_features)
        encoded_text = self.text_encoder(bert_features)

        if encoded_audio.dim() == 1:
            encoded_audio = encoded_audio.unsqueeze(0) 
        if encoded_text.dim() == 1:
            encoded_text = encoded_text.unsqueeze(0)

        combined_features = torch.cat((encoded_text, encoded_audio), dim=1)
        return self.classifier(combined_features)

# %%
def grid_search(train_dataloader, val_dataloader, bert_feature_size, audio_feature_size, num_classes):
    text_encoder_sizes = [128,256, 512]
    text_encoder_depths = [1, 2,3]
    text_encoder_dropouts = [0.3, 0.5,0.7]

    audio_encoder_sizes = [64,128, 256]
    audio_encoder_depths = [1, 2,5]
    audio_encoder_dropouts = [0.3, 0.5,0.7]

    classifier_sizes = [128,256,512, 1024]
    classifier_depths = [1, 2,3]
    classifier_dropouts = [0.3, 0.5,0.7]

    best_model = None
    best_accuracy = 0
    best_params = {}

    for text_size in text_encoder_sizes:
        for text_depth in text_encoder_depths:
            for text_dropout in text_encoder_dropouts:
                for audio_size in audio_encoder_sizes:
                    for audio_depth in audio_encoder_depths:
                        for audio_dropout in audio_encoder_dropouts:
                            for classifier_size in classifier_sizes:
                                for classifier_depth in classifier_depths:
                                    for classifier_dropout in classifier_dropouts:
                                        model = CombinedClassifier(
                                            bert_feature_size=bert_feature_size,
                                            audio_feature_size=audio_feature_size,
                                            num_classes=num_classes,
                                            encoded_audio_size=audio_size,
                                            encoded_text_size=text_size,
                                            audio_depth=audio_depth,
                                            text_depth=text_depth,
                                            classifier_size=classifier_size,
                                            classifier_depth=classifier_depth,
                                            audio_dropout_rate=audio_dropout,
                                            text_dropout_rate=text_dropout,
                                            classifier_dropout_rate=classifier_dropout
                                        )
                                        trainer = ModelTrainer(model, train_dataloader, val_dataloader, f"model_{text_size}_{text_depth}_{text_dropout}_{audio_size}_{audio_depth}_{audio_dropout}_{classifier_size}_{classifier_depth}_{classifier_dropout}", 30, 5)
                                        criterion = nn.CrossEntropyLoss()

                                        trainer.train(criterion)
                                        val_dataloader = DataLoader(val_dataset, batch_size=512, shuffle=False, drop_last=True)
                                        val_loss, val_accuracy = trainer.validate(val_dataloader, criterion)

                                        if val_accuracy > best_accuracy:
                                            best_model = model
                                            best_accuracy = val_accuracy
                                            best_params = {
                                                'text_encoder_size': text_size,
                                                'text_encoder_depth': text_depth,
                                                'text_encoder_dropout': text_dropout,
                                                'audio_encoder_size': audio_size,
                                                'audio_encoder_depth': audio_depth,
                                                'audio_encoder_dropout': audio_dropout,
                                                'classifier_size': classifier_size,
                                                'classifier_depth': classifier_depth,
                                                'classifier_dropout': classifier_dropout
                                            }
                                        print(f"Model with params {best_params} achieved validation accuracy: {val_accuracy}")

    return best_model, best_params

# %%
bert_feature_size, audio_feature_size = 768 , 45 
num_classes = 3 
grid_search(train_dataset, val_dataset, bert_feature_size, audio_feature_size, num_classes)
# Out:
# Loaded checkpoint: 30.pt at epoch 30
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 1, 'classifier_dropout': 0.3} achieved validation accuracy: 0.4775481111903065
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4899, Val Loss: 0.0012, Val Accuracy: 0.4462
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.6041, Val Loss: 0.0011, Val Accuracy: 0.4676
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6308, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6412, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6496, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6580, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6628, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6686, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6732, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6803, Val Loss: 0.0010, Val Accuracy: 0.4954
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6855, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6881, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.7002, Val Loss: 0.0010, Val Accuracy: 0.4911
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.6982, Val Loss: 0.0011, Val Accuracy: 0.4925
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7077, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7142, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7260, Val Loss: 0.0011, Val Accuracy: 0.4904
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7284, Val Loss: 0.0011, Val Accuracy: 0.4875
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7405, Val Loss: 0.0011, Val Accuracy: 0.4897
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7442, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7436, Val Loss: 0.0011, Val Accuracy: 0.4868
# Epoch 22/30, Train Loss: 0.0011, Train Accuracy: 0.7609, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 23/30, Train Loss: 0.0011, Train Accuracy: 0.7627, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7716, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 25/30, Train Loss: 0.0011, Train Accuracy: 0.7753, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 26/30, Train Loss: 0.0010, Train Accuracy: 0.7857, Val Loss: 0.0011, Val Accuracy: 0.4683
# Epoch 27/30, Train Loss: 0.0010, Train Accuracy: 0.7939, Val Loss: 0.0012, Val Accuracy: 0.4683
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7988, Val Loss: 0.0012, Val Accuracy: 0.4754
# Epoch 29/30, Train Loss: 0.0009, Train Accuracy: 0.8068, Val Loss: 0.0012, Val Accuracy: 0.4654
# Epoch 30/30, Train Loss: 0.0009, Train Accuracy: 0.8107, Val Loss: 0.0013, Val Accuracy: 0.4676
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 1, 'classifier_dropout': 0.3} achieved validation accuracy: 0.46756949394155384
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4601, Val Loss: 0.0012, Val Accuracy: 0.4369
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5852, Val Loss: 0.0011, Val Accuracy: 0.4676
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6194, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6332, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 5/30, Train Loss: 0.0016, Train Accuracy: 0.6411, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6505, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6545, Val Loss: 0.0010, Val Accuracy: 0.4890
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6642, Val Loss: 0.0010, Val Accuracy: 0.4840
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6684, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 10/30, Train Loss: 0.0015, Train Accuracy: 0.6696, Val Loss: 0.0010, Val Accuracy: 0.4954
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6789, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6815, Val Loss: 0.0010, Val Accuracy: 0.4833
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6851, Val Loss: 0.0010, Val Accuracy: 0.4882
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6932, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 15/30, Train Loss: 0.0014, Train Accuracy: 0.7023, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7077, Val Loss: 0.0010, Val Accuracy: 0.4911
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7124, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 18/30, Train Loss: 0.0013, Train Accuracy: 0.7148, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 19/30, Train Loss: 0.0013, Train Accuracy: 0.7215, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 20/30, Train Loss: 0.0013, Train Accuracy: 0.7311, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7354, Val Loss: 0.0011, Val Accuracy: 0.4897
# Epoch 22/30, Train Loss: 0.0012, Train Accuracy: 0.7428, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 23/30, Train Loss: 0.0012, Train Accuracy: 0.7523, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 24/30, Train Loss: 0.0012, Train Accuracy: 0.7554, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 25/30, Train Loss: 0.0011, Train Accuracy: 0.7632, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 26/30, Train Loss: 0.0011, Train Accuracy: 0.7716, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 27/30, Train Loss: 0.0011, Train Accuracy: 0.7757, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 28/30, Train Loss: 0.0011, Train Accuracy: 0.7823, Val Loss: 0.0011, Val Accuracy: 0.4704
# Epoch 29/30, Train Loss: 0.0010, Train Accuracy: 0.7932, Val Loss: 0.0011, Val Accuracy: 0.4711
# Epoch 30/30, Train Loss: 0.0010, Train Accuracy: 0.7959, Val Loss: 0.0012, Val Accuracy: 0.4654
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 1, 'classifier_dropout': 0.3} achieved validation accuracy: 0.4654312188168211
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4674, Val Loss: 0.0012, Val Accuracy: 0.4241
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5880, Val Loss: 0.0011, Val Accuracy: 0.4647
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6288, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6439, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6524, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6624, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6639, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6733, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6844, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6913, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6974, Val Loss: 0.0011, Val Accuracy: 0.4968
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7036, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7125, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7233, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7268, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7358, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7383, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7545, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7614, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7704, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7752, Val Loss: 0.0012, Val Accuracy: 0.4740
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7859, Val Loss: 0.0012, Val Accuracy: 0.4768
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7901, Val Loss: 0.0012, Val Accuracy: 0.4697
# Epoch 24/30, Train Loss: 0.0010, Train Accuracy: 0.7968, Val Loss: 0.0012, Val Accuracy: 0.4747
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8093, Val Loss: 0.0013, Val Accuracy: 0.4669
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8114, Val Loss: 0.0013, Val Accuracy: 0.4647
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.8233, Val Loss: 0.0013, Val Accuracy: 0.4661
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8224, Val Loss: 0.0013, Val Accuracy: 0.4654
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8380, Val Loss: 0.0014, Val Accuracy: 0.4754
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8450, Val Loss: 0.0014, Val Accuracy: 0.4683
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 1, 'classifier_dropout': 0.3} achieved validation accuracy: 0.4682822523164647
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4432, Val Loss: 0.0013, Val Accuracy: 0.4070
# Epoch 2/30, Train Loss: 0.0018, Train Accuracy: 0.5717, Val Loss: 0.0012, Val Accuracy: 0.4590
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6154, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6372, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6433, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6522, Val Loss: 0.0011, Val Accuracy: 0.4904
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6589, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6663, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6739, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6791, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6863, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6921, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6993, Val Loss: 0.0011, Val Accuracy: 0.4875
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7080, Val Loss: 0.0011, Val Accuracy: 0.4932
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7077, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7156, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7200, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7339, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7364, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7498, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7471, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 22/30, Train Loss: 0.0011, Train Accuracy: 0.7560, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 23/30, Train Loss: 0.0011, Train Accuracy: 0.7586, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7688, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 25/30, Train Loss: 0.0010, Train Accuracy: 0.7771, Val Loss: 0.0012, Val Accuracy: 0.4733
# Epoch 26/30, Train Loss: 0.0010, Train Accuracy: 0.7836, Val Loss: 0.0012, Val Accuracy: 0.4754
# Epoch 27/30, Train Loss: 0.0010, Train Accuracy: 0.7932, Val Loss: 0.0012, Val Accuracy: 0.4733
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7973, Val Loss: 0.0012, Val Accuracy: 0.4797
# Epoch 29/30, Train Loss: 0.0009, Train Accuracy: 0.8066, Val Loss: 0.0013, Val Accuracy: 0.4740
# Epoch 30/30, Train Loss: 0.0009, Train Accuracy: 0.8124, Val Loss: 0.0013, Val Accuracy: 0.4775
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 1, 'classifier_dropout': 0.3} achieved validation accuracy: 0.4775481111903065
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.3729, Val Loss: 0.0015, Val Accuracy: 0.3849
# Epoch 2/30, Train Loss: 0.0019, Train Accuracy: 0.5009, Val Loss: 0.0012, Val Accuracy: 0.4220
# Epoch 3/30, Train Loss: 0.0017, Train Accuracy: 0.5793, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 4/30, Train Loss: 0.0017, Train Accuracy: 0.6031, Val Loss: 0.0011, Val Accuracy: 0.4711
# Epoch 5/30, Train Loss: 0.0016, Train Accuracy: 0.6221, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 6/30, Train Loss: 0.0016, Train Accuracy: 0.6375, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 7/30, Train Loss: 0.0016, Train Accuracy: 0.6428, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6565, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6533, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 10/30, Train Loss: 0.0015, Train Accuracy: 0.6622, Val Loss: 0.0010, Val Accuracy: 0.4954
# Epoch 11/30, Train Loss: 0.0015, Train Accuracy: 0.6721, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 12/30, Train Loss: 0.0015, Train Accuracy: 0.6705, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 13/30, Train Loss: 0.0015, Train Accuracy: 0.6778, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6848, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 15/30, Train Loss: 0.0014, Train Accuracy: 0.6856, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 16/30, Train Loss: 0.0014, Train Accuracy: 0.6979, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 17/30, Train Loss: 0.0014, Train Accuracy: 0.6965, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 18/30, Train Loss: 0.0014, Train Accuracy: 0.7027, Val Loss: 0.0010, Val Accuracy: 0.4818
# Epoch 19/30, Train Loss: 0.0013, Train Accuracy: 0.7169, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 20/30, Train Loss: 0.0013, Train Accuracy: 0.7198, Val Loss: 0.0011, Val Accuracy: 0.4911
# Epoch 21/30, Train Loss: 0.0013, Train Accuracy: 0.7209, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 22/30, Train Loss: 0.0013, Train Accuracy: 0.7346, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 23/30, Train Loss: 0.0012, Train Accuracy: 0.7429, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 24/30, Train Loss: 0.0012, Train Accuracy: 0.7453, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 25/30, Train Loss: 0.0012, Train Accuracy: 0.7530, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 26/30, Train Loss: 0.0011, Train Accuracy: 0.7601, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 27/30, Train Loss: 0.0011, Train Accuracy: 0.7649, Val Loss: 0.0012, Val Accuracy: 0.4775
# Epoch 28/30, Train Loss: 0.0011, Train Accuracy: 0.7703, Val Loss: 0.0012, Val Accuracy: 0.4804
# Epoch 29/30, Train Loss: 0.0011, Train Accuracy: 0.7805, Val Loss: 0.0012, Val Accuracy: 0.4783
# Epoch 30/30, Train Loss: 0.0010, Train Accuracy: 0.7856, Val Loss: 0.0012, Val Accuracy: 0.4797
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4796863863150392
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.4317, Val Loss: 0.0013, Val Accuracy: 0.3920
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5763, Val Loss: 0.0011, Val Accuracy: 0.4683
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6199, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6407, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6556, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6589, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6654, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6713, Val Loss: 0.0010, Val Accuracy: 0.4982
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6795, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6888, Val Loss: 0.0010, Val Accuracy: 0.4925
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6976, Val Loss: 0.0011, Val Accuracy: 0.4868
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7006, Val Loss: 0.0010, Val Accuracy: 0.4775
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7075, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7207, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7256, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7337, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7412, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7494, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7536, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7629, Val Loss: 0.0012, Val Accuracy: 0.4811
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7720, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7834, Val Loss: 0.0012, Val Accuracy: 0.4747
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7868, Val Loss: 0.0012, Val Accuracy: 0.4740
# Epoch 24/30, Train Loss: 0.0010, Train Accuracy: 0.7968, Val Loss: 0.0012, Val Accuracy: 0.4775
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8035, Val Loss: 0.0013, Val Accuracy: 0.4669
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8034, Val Loss: 0.0013, Val Accuracy: 0.4612
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.8157, Val Loss: 0.0013, Val Accuracy: 0.4733
# Epoch 28/30, Train Loss: 0.0009, Train Accuracy: 0.8201, Val Loss: 0.0013, Val Accuracy: 0.4697
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8257, Val Loss: 0.0014, Val Accuracy: 0.4640
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8287, Val Loss: 0.0014, Val Accuracy: 0.4754
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.47540983606557374
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.3856, Val Loss: 0.0015, Val Accuracy: 0.3785
# Epoch 2/30, Train Loss: 0.0019, Train Accuracy: 0.5266, Val Loss: 0.0012, Val Accuracy: 0.4448
# Epoch 3/30, Train Loss: 0.0017, Train Accuracy: 0.5923, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6289, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 5/30, Train Loss: 0.0016, Train Accuracy: 0.6350, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 6/30, Train Loss: 0.0016, Train Accuracy: 0.6475, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6481, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6604, Val Loss: 0.0010, Val Accuracy: 0.4904
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6655, Val Loss: 0.0010, Val Accuracy: 0.4818
# Epoch 10/30, Train Loss: 0.0015, Train Accuracy: 0.6772, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6792, Val Loss: 0.0010, Val Accuracy: 0.4811
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6889, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6936, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6922, Val Loss: 0.0010, Val Accuracy: 0.4818
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7021, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7067, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7128, Val Loss: 0.0011, Val Accuracy: 0.4704
# Epoch 18/30, Train Loss: 0.0013, Train Accuracy: 0.7251, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 19/30, Train Loss: 0.0013, Train Accuracy: 0.7350, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7300, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7494, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 22/30, Train Loss: 0.0012, Train Accuracy: 0.7492, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 23/30, Train Loss: 0.0012, Train Accuracy: 0.7525, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7598, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 25/30, Train Loss: 0.0011, Train Accuracy: 0.7645, Val Loss: 0.0012, Val Accuracy: 0.4854
# Epoch 26/30, Train Loss: 0.0011, Train Accuracy: 0.7780, Val Loss: 0.0012, Val Accuracy: 0.4804
# Epoch 27/30, Train Loss: 0.0011, Train Accuracy: 0.7728, Val Loss: 0.0012, Val Accuracy: 0.4790
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7849, Val Loss: 0.0012, Val Accuracy: 0.4818
# Epoch 29/30, Train Loss: 0.0010, Train Accuracy: 0.7857, Val Loss: 0.0012, Val Accuracy: 0.4654
# Epoch 30/30, Train Loss: 0.0010, Train Accuracy: 0.7965, Val Loss: 0.0012, Val Accuracy: 0.4669
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4668567355666429
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.3382, Val Loss: 0.0016, Val Accuracy: 0.3877
# Epoch 2/30, Train Loss: 0.0021, Train Accuracy: 0.3961, Val Loss: 0.0014, Val Accuracy: 0.3820
# Epoch 3/30, Train Loss: 0.0019, Train Accuracy: 0.5175, Val Loss: 0.0012, Val Accuracy: 0.4141
# Epoch 4/30, Train Loss: 0.0018, Train Accuracy: 0.5622, Val Loss: 0.0012, Val Accuracy: 0.4312
# Epoch 5/30, Train Loss: 0.0017, Train Accuracy: 0.5811, Val Loss: 0.0011, Val Accuracy: 0.4433
# Epoch 6/30, Train Loss: 0.0017, Train Accuracy: 0.5901, Val Loss: 0.0011, Val Accuracy: 0.4462
# Epoch 7/30, Train Loss: 0.0017, Train Accuracy: 0.6044, Val Loss: 0.0011, Val Accuracy: 0.4555
# Epoch 8/30, Train Loss: 0.0017, Train Accuracy: 0.6071, Val Loss: 0.0011, Val Accuracy: 0.4619
# Epoch 9/30, Train Loss: 0.0016, Train Accuracy: 0.6138, Val Loss: 0.0011, Val Accuracy: 0.4590
# Epoch 10/30, Train Loss: 0.0016, Train Accuracy: 0.6234, Val Loss: 0.0011, Val Accuracy: 0.4690
# Epoch 11/30, Train Loss: 0.0016, Train Accuracy: 0.6311, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 12/30, Train Loss: 0.0016, Train Accuracy: 0.6354, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 13/30, Train Loss: 0.0015, Train Accuracy: 0.6396, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 14/30, Train Loss: 0.0015, Train Accuracy: 0.6521, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 15/30, Train Loss: 0.0015, Train Accuracy: 0.6561, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 16/30, Train Loss: 0.0015, Train Accuracy: 0.6593, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 17/30, Train Loss: 0.0015, Train Accuracy: 0.6710, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 18/30, Train Loss: 0.0015, Train Accuracy: 0.6774, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 19/30, Train Loss: 0.0014, Train Accuracy: 0.6800, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 20/30, Train Loss: 0.0014, Train Accuracy: 0.6860, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 21/30, Train Loss: 0.0014, Train Accuracy: 0.6882, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 22/30, Train Loss: 0.0014, Train Accuracy: 0.6905, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 23/30, Train Loss: 0.0014, Train Accuracy: 0.6998, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 24/30, Train Loss: 0.0014, Train Accuracy: 0.7007, Val Loss: 0.0011, Val Accuracy: 0.4704
# Epoch 25/30, Train Loss: 0.0014, Train Accuracy: 0.7045, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 26/30, Train Loss: 0.0013, Train Accuracy: 0.7111, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 27/30, Train Loss: 0.0013, Train Accuracy: 0.7062, Val Loss: 0.0011, Val Accuracy: 0.4711
# Epoch 28/30, Train Loss: 0.0013, Train Accuracy: 0.7207, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 29/30, Train Loss: 0.0013, Train Accuracy: 0.7358, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 30/30, Train Loss: 0.0013, Train Accuracy: 0.7297, Val Loss: 0.0011, Val Accuracy: 0.4726
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.47255880256593014
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0019, Train Accuracy: 0.5090, Val Loss: 0.0011, Val Accuracy: 0.4583
# Epoch 2/30, Train Loss: 0.0016, Train Accuracy: 0.6100, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6335, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6447, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6577, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6619, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6699, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6811, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6831, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6911, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 11/30, Train Loss: 0.0013, Train Accuracy: 0.6966, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7030, Val Loss: 0.0010, Val Accuracy: 0.4947
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7131, Val Loss: 0.0010, Val Accuracy: 0.5011
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7230, Val Loss: 0.0011, Val Accuracy: 0.4947
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7290, Val Loss: 0.0011, Val Accuracy: 0.4868
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7373, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7420, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7513, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7606, Val Loss: 0.0011, Val Accuracy: 0.4904
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7696, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7785, Val Loss: 0.0012, Val Accuracy: 0.4747
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7844, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7873, Val Loss: 0.0012, Val Accuracy: 0.4654
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.8044, Val Loss: 0.0012, Val Accuracy: 0.4704
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8060, Val Loss: 0.0012, Val Accuracy: 0.4690
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8183, Val Loss: 0.0013, Val Accuracy: 0.4669
# Epoch 27/30, Train Loss: 0.0008, Train Accuracy: 0.8250, Val Loss: 0.0013, Val Accuracy: 0.4654
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8339, Val Loss: 0.0013, Val Accuracy: 0.4747
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8393, Val Loss: 0.0013, Val Accuracy: 0.4704
# Epoch 30/30, Train Loss: 0.0007, Train Accuracy: 0.8458, Val Loss: 0.0013, Val Accuracy: 0.4683
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4682822523164647
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0019, Train Accuracy: 0.4969, Val Loss: 0.0012, Val Accuracy: 0.4519
# Epoch 2/30, Train Loss: 0.0016, Train Accuracy: 0.6100, Val Loss: 0.0011, Val Accuracy: 0.4711
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6362, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6395, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6534, Val Loss: 0.0011, Val Accuracy: 0.4911
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6635, Val Loss: 0.0010, Val Accuracy: 0.4911
# Epoch 7/30, Train Loss: 0.0014, Train Accuracy: 0.6746, Val Loss: 0.0010, Val Accuracy: 0.5011
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6764, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6811, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6865, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6877, Val Loss: 0.0010, Val Accuracy: 0.4833
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.6958, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7092, Val Loss: 0.0010, Val Accuracy: 0.4818
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7156, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7207, Val Loss: 0.0011, Val Accuracy: 0.4890
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7278, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7341, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7428, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7559, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7593, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7721, Val Loss: 0.0012, Val Accuracy: 0.4718
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7824, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7821, Val Loss: 0.0012, Val Accuracy: 0.4683
# Epoch 24/30, Train Loss: 0.0010, Train Accuracy: 0.7884, Val Loss: 0.0012, Val Accuracy: 0.4661
# Epoch 25/30, Train Loss: 0.0010, Train Accuracy: 0.7993, Val Loss: 0.0012, Val Accuracy: 0.4683
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8063, Val Loss: 0.0012, Val Accuracy: 0.4733
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.8170, Val Loss: 0.0012, Val Accuracy: 0.4761
# Epoch 28/30, Train Loss: 0.0009, Train Accuracy: 0.8214, Val Loss: 0.0013, Val Accuracy: 0.4761
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8295, Val Loss: 0.0013, Val Accuracy: 0.4733
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8326, Val Loss: 0.0013, Val Accuracy: 0.4690
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4689950106913756
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4787, Val Loss: 0.0012, Val Accuracy: 0.4512
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.6027, Val Loss: 0.0011, Val Accuracy: 0.4683
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6322, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6432, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6507, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6586, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6627, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6700, Val Loss: 0.0010, Val Accuracy: 0.4861
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6770, Val Loss: 0.0010, Val Accuracy: 0.4918
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6823, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6824, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6894, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7044, Val Loss: 0.0010, Val Accuracy: 0.4847
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7094, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7143, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7260, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7258, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7368, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7516, Val Loss: 0.0011, Val Accuracy: 0.4868
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7533, Val Loss: 0.0011, Val Accuracy: 0.4875
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7658, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 22/30, Train Loss: 0.0011, Train Accuracy: 0.7775, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7793, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 24/30, Train Loss: 0.0010, Train Accuracy: 0.7896, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 25/30, Train Loss: 0.0010, Train Accuracy: 0.7920, Val Loss: 0.0012, Val Accuracy: 0.4790
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8046, Val Loss: 0.0012, Val Accuracy: 0.4718
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.8090, Val Loss: 0.0012, Val Accuracy: 0.4818
# Epoch 28/30, Train Loss: 0.0009, Train Accuracy: 0.8214, Val Loss: 0.0012, Val Accuracy: 0.4761
# Epoch 29/30, Train Loss: 0.0009, Train Accuracy: 0.8251, Val Loss: 0.0013, Val Accuracy: 0.4669
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8325, Val Loss: 0.0013, Val Accuracy: 0.4768
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4768353528153956
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4776, Val Loss: 0.0012, Val Accuracy: 0.4519
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.6032, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6303, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6483, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6528, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6615, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 7/30, Train Loss: 0.0014, Train Accuracy: 0.6708, Val Loss: 0.0010, Val Accuracy: 0.4932
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6811, Val Loss: 0.0010, Val Accuracy: 0.4932
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6852, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6909, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 11/30, Train Loss: 0.0013, Train Accuracy: 0.6984, Val Loss: 0.0010, Val Accuracy: 0.4804
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7056, Val Loss: 0.0010, Val Accuracy: 0.4882
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7180, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7264, Val Loss: 0.0011, Val Accuracy: 0.4932
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7357, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7456, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 17/30, Train Loss: 0.0011, Train Accuracy: 0.7528, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7649, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7759, Val Loss: 0.0012, Val Accuracy: 0.4733
# Epoch 20/30, Train Loss: 0.0010, Train Accuracy: 0.7860, Val Loss: 0.0012, Val Accuracy: 0.4761
# Epoch 21/30, Train Loss: 0.0010, Train Accuracy: 0.7865, Val Loss: 0.0012, Val Accuracy: 0.4704
# Epoch 22/30, Train Loss: 0.0009, Train Accuracy: 0.8029, Val Loss: 0.0012, Val Accuracy: 0.4661
# Epoch 23/30, Train Loss: 0.0009, Train Accuracy: 0.8037, Val Loss: 0.0013, Val Accuracy: 0.4740
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.8148, Val Loss: 0.0013, Val Accuracy: 0.4576
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8214, Val Loss: 0.0013, Val Accuracy: 0.4590
# Epoch 26/30, Train Loss: 0.0008, Train Accuracy: 0.8333, Val Loss: 0.0014, Val Accuracy: 0.4540
# Epoch 27/30, Train Loss: 0.0008, Train Accuracy: 0.8310, Val Loss: 0.0014, Val Accuracy: 0.4647
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8386, Val Loss: 0.0014, Val Accuracy: 0.4683
# Epoch 29/30, Train Loss: 0.0007, Train Accuracy: 0.8399, Val Loss: 0.0014, Val Accuracy: 0.4626
# Epoch 30/30, Train Loss: 0.0007, Train Accuracy: 0.8477, Val Loss: 0.0014, Val Accuracy: 0.4619
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.46186742694226657
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4504, Val Loss: 0.0012, Val Accuracy: 0.4376
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5902, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6287, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6432, Val Loss: 0.0010, Val Accuracy: 0.4904
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6544, Val Loss: 0.0010, Val Accuracy: 0.4932
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6608, Val Loss: 0.0010, Val Accuracy: 0.4904
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6671, Val Loss: 0.0010, Val Accuracy: 0.4932
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6724, Val Loss: 0.0010, Val Accuracy: 0.4982
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6801, Val Loss: 0.0010, Val Accuracy: 0.4882
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6889, Val Loss: 0.0010, Val Accuracy: 0.4939
# Epoch 11/30, Train Loss: 0.0013, Train Accuracy: 0.7033, Val Loss: 0.0010, Val Accuracy: 0.4954
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7046, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7159, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7250, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7315, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7401, Val Loss: 0.0011, Val Accuracy: 0.4875
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7474, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7545, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7615, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7762, Val Loss: 0.0012, Val Accuracy: 0.4768
# Epoch 21/30, Train Loss: 0.0010, Train Accuracy: 0.7787, Val Loss: 0.0012, Val Accuracy: 0.4726
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7923, Val Loss: 0.0012, Val Accuracy: 0.4790
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7966, Val Loss: 0.0012, Val Accuracy: 0.4754
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.8061, Val Loss: 0.0013, Val Accuracy: 0.4711
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8114, Val Loss: 0.0013, Val Accuracy: 0.4754
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8212, Val Loss: 0.0013, Val Accuracy: 0.4704
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.8211, Val Loss: 0.0013, Val Accuracy: 0.4797
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8333, Val Loss: 0.0013, Val Accuracy: 0.4612
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8365, Val Loss: 0.0014, Val Accuracy: 0.4790
# Epoch 30/30, Train Loss: 0.0007, Train Accuracy: 0.8477, Val Loss: 0.0014, Val Accuracy: 0.4640
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4640057020669993
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.4116, Val Loss: 0.0013, Val Accuracy: 0.3849
# Epoch 2/30, Train Loss: 0.0018, Train Accuracy: 0.5487, Val Loss: 0.0012, Val Accuracy: 0.4440
# Epoch 3/30, Train Loss: 0.0017, Train Accuracy: 0.5928, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6207, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 5/30, Train Loss: 0.0016, Train Accuracy: 0.6356, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6475, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6496, Val Loss: 0.0010, Val Accuracy: 0.4797
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6613, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6614, Val Loss: 0.0010, Val Accuracy: 0.4804
# Epoch 10/30, Train Loss: 0.0015, Train Accuracy: 0.6734, Val Loss: 0.0010, Val Accuracy: 0.4825
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6730, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6797, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6783, Val Loss: 0.0011, Val Accuracy: 0.4890
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6881, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 15/30, Train Loss: 0.0014, Train Accuracy: 0.6944, Val Loss: 0.0010, Val Accuracy: 0.4833
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7066, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7107, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 18/30, Train Loss: 0.0013, Train Accuracy: 0.7128, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 19/30, Train Loss: 0.0013, Train Accuracy: 0.7248, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7358, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7336, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 22/30, Train Loss: 0.0012, Train Accuracy: 0.7426, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 23/30, Train Loss: 0.0012, Train Accuracy: 0.7509, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7576, Val Loss: 0.0011, Val Accuracy: 0.4711
# Epoch 25/30, Train Loss: 0.0011, Train Accuracy: 0.7611, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 26/30, Train Loss: 0.0011, Train Accuracy: 0.7714, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 27/30, Train Loss: 0.0010, Train Accuracy: 0.7791, Val Loss: 0.0012, Val Accuracy: 0.4754
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7865, Val Loss: 0.0012, Val Accuracy: 0.4647
# Epoch 29/30, Train Loss: 0.0010, Train Accuracy: 0.7858, Val Loss: 0.0012, Val Accuracy: 0.4783
# Epoch 30/30, Train Loss: 0.0010, Train Accuracy: 0.7987, Val Loss: 0.0012, Val Accuracy: 0.4790
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 64, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.3, 'classifier_size': 128, 'classifier_depth': 2, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4789736279401283
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4596, Val Loss: 0.0012, Val Accuracy: 0.4241
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5937, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6335, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6466, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6533, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6702, Val Loss: 0.0010, Val Accuracy: 0.4840
# Epoch 7/30, Train Loss: 0.0014, Train Accuracy: 0.6718, Val Loss: 0.0010, Val Accuracy: 0.4854
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6858, Val Loss: 0.0010, Val Accuracy: 0.4840
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6929, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 10/30, Train Loss: 0.0013, Train Accuracy: 0.7018, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 11/30, Train Loss: 0.0013, Train Accuracy: 0.7057, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7065, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7256, Val Loss: 0.0011, Val Accuracy: 0.4818
# Epoch 14/30, Train Loss: 0.0012, Train Accuracy: 0.7311, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7503, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 16/30, Train Loss: 0.0011, Train Accuracy: 0.7567, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 17/30, Train Loss: 0.0011, Train Accuracy: 0.7565, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7740, Val Loss: 0.0012, Val Accuracy: 0.4654
# Epoch 19/30, Train Loss: 0.0010, Train Accuracy: 0.7723, Val Loss: 0.0012, Val Accuracy: 0.4690
# Epoch 20/30, Train Loss: 0.0010, Train Accuracy: 0.7903, Val Loss: 0.0012, Val Accuracy: 0.4775
# Epoch 21/30, Train Loss: 0.0010, Train Accuracy: 0.7923, Val Loss: 0.0012, Val Accuracy: 0.4718
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7951, Val Loss: 0.0012, Val Accuracy: 0.4733
# Epoch 23/30, Train Loss: 0.0009, Train Accuracy: 0.8089, Val Loss: 0.0013, Val Accuracy: 0.4647
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.8113, Val Loss: 0.0013, Val Accuracy: 0.4697
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8245, Val Loss: 0.0013, Val Accuracy: 0.4683
# Epoch 26/30, Train Loss: 0.0008, Train Accuracy: 0.8252, Val Loss: 0.0013, Val Accuracy: 0.4562
# ...
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6709, Val Loss: 0.0011, Val Accuracy: 0.4947
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6694, Val Loss: 0.0010, Val Accuracy: 0.4954
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6794, Val Loss: 0.0010, Val Accuracy: 0.4982
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6858, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6877, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6983, Val Loss: 0.0010, Val Accuracy: 0.4804
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7074, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7122, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7168, Val Loss: 0.0011, Val Accuracy: 0.4740
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7209, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7300, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7452, Val Loss: 0.0011, Val Accuracy: 0.4683
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7487, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 22/30, Train Loss: 0.0011, Train Accuracy: 0.7529, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 23/30, Train Loss: 0.0011, Train Accuracy: 0.7615, Val Loss: 0.0011, Val Accuracy: 0.4640
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7728, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 25/30, Train Loss: 0.0010, Train Accuracy: 0.7795, Val Loss: 0.0012, Val Accuracy: 0.4783
# Epoch 26/30, Train Loss: 0.0010, Train Accuracy: 0.7834, Val Loss: 0.0012, Val Accuracy: 0.4633
# Epoch 27/30, Train Loss: 0.0010, Train Accuracy: 0.7948, Val Loss: 0.0012, Val Accuracy: 0.4619
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7962, Val Loss: 0.0012, Val Accuracy: 0.4676
# Epoch 29/30, Train Loss: 0.0009, Train Accuracy: 0.8081, Val Loss: 0.0012, Val Accuracy: 0.4697
# Epoch 30/30, Train Loss: 0.0009, Train Accuracy: 0.8127, Val Loss: 0.0013, Val Accuracy: 0.4661
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 256, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.7, 'classifier_size': 256, 'classifier_depth': 3, 'classifier_dropout': 0.7} achieved validation accuracy: 0.466143977191732
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4597, Val Loss: 0.0012, Val Accuracy: 0.4355
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5998, Val Loss: 0.0011, Val Accuracy: 0.4704
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6323, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6438, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6561, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6557, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6616, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6743, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6802, Val Loss: 0.0010, Val Accuracy: 0.4797
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6772, Val Loss: 0.0011, Val Accuracy: 0.4911
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6952, Val Loss: 0.0010, Val Accuracy: 0.4925
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.6954, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7116, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7190, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7240, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7343, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7365, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7508, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7607, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7683, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 21/30, Train Loss: 0.0010, Train Accuracy: 0.7742, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.7760, Val Loss: 0.0012, Val Accuracy: 0.4783
# Epoch 23/30, Train Loss: 0.0009, Train Accuracy: 0.7989, Val Loss: 0.0012, Val Accuracy: 0.4811
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.7920, Val Loss: 0.0012, Val Accuracy: 0.4804
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8044, Val Loss: 0.0012, Val Accuracy: 0.4854
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8138, Val Loss: 0.0013, Val Accuracy: 0.4775
# Epoch 27/30, Train Loss: 0.0008, Train Accuracy: 0.8188, Val Loss: 0.0013, Val Accuracy: 0.4783
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8297, Val Loss: 0.0013, Val Accuracy: 0.4761
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8333, Val Loss: 0.0013, Val Accuracy: 0.4797
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8374, Val Loss: 0.0013, Val Accuracy: 0.4761
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 256, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.7, 'classifier_size': 256, 'classifier_depth': 3, 'classifier_dropout': 0.7} achieved validation accuracy: 0.47612259444048466
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4402, Val Loss: 0.0012, Val Accuracy: 0.4184
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.5921, Val Loss: 0.0011, Val Accuracy: 0.4718
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6240, Val Loss: 0.0011, Val Accuracy: 0.4811
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6432, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6494, Val Loss: 0.0011, Val Accuracy: 0.4904
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6574, Val Loss: 0.0010, Val Accuracy: 0.4811
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6643, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6629, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6742, Val Loss: 0.0010, Val Accuracy: 0.4932
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6797, Val Loss: 0.0010, Val Accuracy: 0.4968
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6859, Val Loss: 0.0011, Val Accuracy: 0.4911
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6951, Val Loss: 0.0010, Val Accuracy: 0.4868
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7014, Val Loss: 0.0010, Val Accuracy: 0.4790
# Epoch 14/30, Train Loss: 0.0013, Train Accuracy: 0.7121, Val Loss: 0.0011, Val Accuracy: 0.4875
# Epoch 15/30, Train Loss: 0.0013, Train Accuracy: 0.7074, Val Loss: 0.0011, Val Accuracy: 0.4847
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7211, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7338, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 18/30, Train Loss: 0.0012, Train Accuracy: 0.7381, Val Loss: 0.0011, Val Accuracy: 0.4861
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7395, Val Loss: 0.0011, Val Accuracy: 0.4697
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7505, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 21/30, Train Loss: 0.0011, Train Accuracy: 0.7645, Val Loss: 0.0012, Val Accuracy: 0.4790
# Epoch 22/30, Train Loss: 0.0011, Train Accuracy: 0.7693, Val Loss: 0.0011, Val Accuracy: 0.4676
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.7822, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 24/30, Train Loss: 0.0010, Train Accuracy: 0.7761, Val Loss: 0.0012, Val Accuracy: 0.4704
# Epoch 25/30, Train Loss: 0.0010, Train Accuracy: 0.7908, Val Loss: 0.0013, Val Accuracy: 0.4718
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.7985, Val Loss: 0.0013, Val Accuracy: 0.4690
# Epoch 27/30, Train Loss: 0.0009, Train Accuracy: 0.7974, Val Loss: 0.0012, Val Accuracy: 0.4704
# Epoch 28/30, Train Loss: 0.0009, Train Accuracy: 0.8099, Val Loss: 0.0013, Val Accuracy: 0.4683
# Epoch 29/30, Train Loss: 0.0009, Train Accuracy: 0.8208, Val Loss: 0.0013, Val Accuracy: 0.4704
# Epoch 30/30, Train Loss: 0.0008, Train Accuracy: 0.8259, Val Loss: 0.0013, Val Accuracy: 0.4775
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 256, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.7, 'classifier_size': 256, 'classifier_depth': 3, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4775481111903065
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0021, Train Accuracy: 0.3803, Val Loss: 0.0013, Val Accuracy: 0.3934
# Epoch 2/30, Train Loss: 0.0018, Train Accuracy: 0.5367, Val Loss: 0.0012, Val Accuracy: 0.4569
# Epoch 3/30, Train Loss: 0.0017, Train Accuracy: 0.6008, Val Loss: 0.0011, Val Accuracy: 0.4768
# Epoch 4/30, Train Loss: 0.0016, Train Accuracy: 0.6196, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 5/30, Train Loss: 0.0016, Train Accuracy: 0.6410, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6471, Val Loss: 0.0011, Val Accuracy: 0.4897
# Epoch 7/30, Train Loss: 0.0015, Train Accuracy: 0.6532, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 8/30, Train Loss: 0.0015, Train Accuracy: 0.6547, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 9/30, Train Loss: 0.0015, Train Accuracy: 0.6608, Val Loss: 0.0010, Val Accuracy: 0.4890
# Epoch 10/30, Train Loss: 0.0015, Train Accuracy: 0.6644, Val Loss: 0.0010, Val Accuracy: 0.4875
# Epoch 11/30, Train Loss: 0.0014, Train Accuracy: 0.6736, Val Loss: 0.0011, Val Accuracy: 0.4975
# Epoch 12/30, Train Loss: 0.0014, Train Accuracy: 0.6816, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 13/30, Train Loss: 0.0014, Train Accuracy: 0.6857, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 14/30, Train Loss: 0.0014, Train Accuracy: 0.6895, Val Loss: 0.0010, Val Accuracy: 0.4897
# Epoch 15/30, Train Loss: 0.0014, Train Accuracy: 0.6957, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 16/30, Train Loss: 0.0013, Train Accuracy: 0.7045, Val Loss: 0.0011, Val Accuracy: 0.4911
# Epoch 17/30, Train Loss: 0.0013, Train Accuracy: 0.7090, Val Loss: 0.0011, Val Accuracy: 0.4754
# Epoch 18/30, Train Loss: 0.0013, Train Accuracy: 0.7179, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 19/30, Train Loss: 0.0012, Train Accuracy: 0.7267, Val Loss: 0.0011, Val Accuracy: 0.4925
# Epoch 20/30, Train Loss: 0.0012, Train Accuracy: 0.7301, Val Loss: 0.0011, Val Accuracy: 0.4840
# Epoch 21/30, Train Loss: 0.0012, Train Accuracy: 0.7328, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 22/30, Train Loss: 0.0012, Train Accuracy: 0.7394, Val Loss: 0.0011, Val Accuracy: 0.4661
# Epoch 23/30, Train Loss: 0.0011, Train Accuracy: 0.7550, Val Loss: 0.0011, Val Accuracy: 0.4733
# Epoch 24/30, Train Loss: 0.0011, Train Accuracy: 0.7619, Val Loss: 0.0011, Val Accuracy: 0.4783
# Epoch 25/30, Train Loss: 0.0011, Train Accuracy: 0.7662, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 26/30, Train Loss: 0.0011, Train Accuracy: 0.7709, Val Loss: 0.0012, Val Accuracy: 0.4768
# Epoch 27/30, Train Loss: 0.0010, Train Accuracy: 0.7799, Val Loss: 0.0012, Val Accuracy: 0.4718
# Epoch 28/30, Train Loss: 0.0010, Train Accuracy: 0.7861, Val Loss: 0.0012, Val Accuracy: 0.4669
# Epoch 29/30, Train Loss: 0.0010, Train Accuracy: 0.7944, Val Loss: 0.0012, Val Accuracy: 0.4726
# Epoch 30/30, Train Loss: 0.0009, Train Accuracy: 0.7993, Val Loss: 0.0013, Val Accuracy: 0.4619
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 256, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.7, 'classifier_size': 256, 'classifier_depth': 3, 'classifier_dropout': 0.7} achieved validation accuracy: 0.46186742694226657
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0019, Train Accuracy: 0.5011, Val Loss: 0.0012, Val Accuracy: 0.4476
# Epoch 2/30, Train Loss: 0.0016, Train Accuracy: 0.6092, Val Loss: 0.0011, Val Accuracy: 0.4690
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6353, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6464, Val Loss: 0.0011, Val Accuracy: 0.4761
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6570, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6646, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 7/30, Train Loss: 0.0014, Train Accuracy: 0.6776, Val Loss: 0.0011, Val Accuracy: 0.4882
# Epoch 8/30, Train Loss: 0.0014, Train Accuracy: 0.6744, Val Loss: 0.0011, Val Accuracy: 0.4868
# Epoch 9/30, Train Loss: 0.0014, Train Accuracy: 0.6863, Val Loss: 0.0011, Val Accuracy: 0.4790
# Epoch 10/30, Train Loss: 0.0014, Train Accuracy: 0.6952, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 11/30, Train Loss: 0.0013, Train Accuracy: 0.6995, Val Loss: 0.0011, Val Accuracy: 0.4804
# Epoch 12/30, Train Loss: 0.0013, Train Accuracy: 0.7116, Val Loss: 0.0011, Val Accuracy: 0.4833
# Epoch 13/30, Train Loss: 0.0013, Train Accuracy: 0.7240, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 14/30, Train Loss: 0.0012, Train Accuracy: 0.7310, Val Loss: 0.0011, Val Accuracy: 0.4825
# Epoch 15/30, Train Loss: 0.0012, Train Accuracy: 0.7389, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 16/30, Train Loss: 0.0012, Train Accuracy: 0.7467, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 17/30, Train Loss: 0.0012, Train Accuracy: 0.7462, Val Loss: 0.0011, Val Accuracy: 0.4775
# Epoch 18/30, Train Loss: 0.0011, Train Accuracy: 0.7635, Val Loss: 0.0011, Val Accuracy: 0.4854
# Epoch 19/30, Train Loss: 0.0011, Train Accuracy: 0.7726, Val Loss: 0.0011, Val Accuracy: 0.4726
# Epoch 20/30, Train Loss: 0.0011, Train Accuracy: 0.7790, Val Loss: 0.0011, Val Accuracy: 0.4690
# Epoch 21/30, Train Loss: 0.0010, Train Accuracy: 0.7868, Val Loss: 0.0012, Val Accuracy: 0.4704
# Epoch 22/30, Train Loss: 0.0010, Train Accuracy: 0.8004, Val Loss: 0.0012, Val Accuracy: 0.4797
# Epoch 23/30, Train Loss: 0.0010, Train Accuracy: 0.8017, Val Loss: 0.0012, Val Accuracy: 0.4676
# Epoch 24/30, Train Loss: 0.0009, Train Accuracy: 0.8093, Val Loss: 0.0012, Val Accuracy: 0.4811
# Epoch 25/30, Train Loss: 0.0009, Train Accuracy: 0.8146, Val Loss: 0.0012, Val Accuracy: 0.4654
# Epoch 26/30, Train Loss: 0.0009, Train Accuracy: 0.8222, Val Loss: 0.0012, Val Accuracy: 0.4697
# Epoch 27/30, Train Loss: 0.0008, Train Accuracy: 0.8328, Val Loss: 0.0012, Val Accuracy: 0.4718
# Epoch 28/30, Train Loss: 0.0008, Train Accuracy: 0.8421, Val Loss: 0.0013, Val Accuracy: 0.4683
# Epoch 29/30, Train Loss: 0.0008, Train Accuracy: 0.8495, Val Loss: 0.0013, Val Accuracy: 0.4647
# Epoch 30/30, Train Loss: 0.0007, Train Accuracy: 0.8497, Val Loss: 0.0013, Val Accuracy: 0.4633
# Model with params {'text_encoder_size': 128, 'text_encoder_depth': 1, 'text_encoder_dropout': 0.3, 'audio_encoder_size': 256, 'audio_encoder_depth': 1, 'audio_encoder_dropout': 0.7, 'classifier_size': 256, 'classifier_depth': 3, 'classifier_dropout': 0.7} achieved validation accuracy: 0.4632929436920884
# No checkpoints found, starting from scratch.
# Epoch 1/30, Train Loss: 0.0020, Train Accuracy: 0.4875, Val Loss: 0.0012, Val Accuracy: 0.4455
# Epoch 2/30, Train Loss: 0.0017, Train Accuracy: 0.6008, Val Loss: 0.0011, Val Accuracy: 0.4747
# Epoch 3/30, Train Loss: 0.0016, Train Accuracy: 0.6362, Val Loss: 0.0011, Val Accuracy: 0.4797
# Epoch 4/30, Train Loss: 0.0015, Train Accuracy: 0.6481, Val Loss: 0.0011, Val Accuracy: 0.4897
# Epoch 5/30, Train Loss: 0.0015, Train Accuracy: 0.6525, Val Loss: 0.0011, Val Accuracy: 0.4947
# Epoch 6/30, Train Loss: 0.0015, Train Accuracy: 0.6610, Val Loss: 0.0011, Val Accuracy: 0.4833
